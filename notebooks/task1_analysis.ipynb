# %%
import sys
sys.path.append("/Users/irbaazpatel/NER_Feature_Engineering/scripts")

from preprocess import preprocess_dataset
import pandas as pd

# Define file paths for the four datasets
input_files = [
    "/Users/irbaazpatel/NER_Feature_Engineering/data/politifact_fake.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/data/politifact_real.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/data/gossipcop_fake.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/data/gossipcop_real.csv"
]

# Define output file paths for each dataset after preprocessing
output_files = [
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_real.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_fake.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_real.csv"
]

# Preprocess each dataset
for input_file, output_file in zip(input_files, output_files):
    preprocess_dataset(input_file, output_file)
    print(f"Preprocessing completed for {input_file}")

# Verify the output by reading and displaying the first few rows of each processed dataset
for output_file in output_files:
    processed_data = pd.read_csv(output_file)
    print(f"Preview of {output_file}:")
    display(processed_data.head())  # Use display for better output in Jupyter notebooks
# Out:
# Preprocessed data saved to /Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake.csv
# Preprocessing completed for /Users/irbaazpatel/NER_Feature_Engineering/data/politifact_fake.csv
# Preprocessed data saved to /Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_real.csv
# Preprocessing completed for /Users/irbaazpatel/NER_Feature_Engineering/data/politifact_real.csv
# Preprocessed data saved to /Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_fake.csv
# Preprocessing completed for /Users/irbaazpatel/NER_Feature_Engineering/data/gossipcop_fake.csv
# Preprocessed data saved to /Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_real.csv
# Preprocessing completed for /Users/irbaazpatel/NER_Feature_Engineering/data/gossipcop_real.csv
# Preview of /Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake.csv:
#                 id                                           news_url  \
# ...

# %%
# Import necessary libraries
import sys
import pandas as pd

# Add path for scripts/ directory
sys.path.append("../scripts")

# Import the NER extraction function
from ner_extraction import ner_extraction

# Define paths for all preprocessed datasets
input_files = [
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_real.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_fake.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_real.csv"
]

# Define output file paths for the results with NER
output_files = [
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake_with_ner.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_real_with_ner.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_fake_with_ner.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_real_with_ner.csv"
]

# Run NER extraction on each dataset
for input_file, output_file in zip(input_files, output_files):
    print(f"Processing {input_file}...")
    ner_extraction(input_file, output_file)

# Verify that the NER extraction worked by displaying the first few rows of each result
for output_file in output_files:
    processed_data = pd.read_csv(output_file)
    print(f"\nFirst few rows of {output_file}:")
    print(processed_data.head())
# Out:
# Processing /Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake.csv...
# NER extraction complete. Results saved to /Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake_with_ner.csv
# Processing /Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_real.csv...
# NER extraction complete. Results saved to /Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_real_with_ner.csv
# Processing /Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_fake.csv...
# NER extraction complete. Results saved to /Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_fake_with_ner.csv
# Processing /Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_real.csv...
# NER extraction complete. Results saved to /Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_real_with_ner.csv
#
# ...

# %%
import pandas as pd
from feature_engineering import feature_engineering

# Define paths for all preprocessed datasets
input_files = [
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake_with_ner.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_real_with_ner.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_fake_with_ner.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_real_with_ner.csv"
]


# Define output file paths for the results with NER
output_files = [
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_fake_with_ner_feature-engineering.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_politifact_real_with_ner_feature-engineering.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_fake_with_ner_feature-engineering.csv",
    "/Users/irbaazpatel/NER_Feature_Engineering/output/processed_gossipcop_real_with_ner_feature-engineering.csv"
]

# Perform feature engineering
feature_engineering(input_file, output_file)

# Verify the output
feature_engineered_data = pd.read_csv(output_file)
feature_engineered_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PERSON'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 22
#      14 output_files = [
# ...
